-- %% [markdown]
-- # **Blended Mobility, Porto** | Teaching Computation — The 2nd Cycle
--
-- ### Tue, Jun 27, 14h30 - 17h30 (GMT+1)
--
--
-- ![erasmus-consortium-short.png](attachment:71ce7cc0-487b-4ef2-82b9-b100298a53d9.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
--
-- ## **PART V** | Dictionaries

-- %% [markdown]
-- ---
-- ![image.png](attachment:44ef22d9-deb3-44d0-972f-b961a6ca4df2.png)

-- %%
portuguese = ["gato", "casa", "ovo", "raposa"]
english = ["cat","house","egg","fox"]

-- %%
portuguese # english

-- %%
english # portuguese

-- %% [markdown]
-- ---
-- ![image.png](attachment:03385f4f-db7c-4834-89d7-dec930976472.png)

-- %%
portuguese # (english # english)

-- %%
(portuguese # english) # english

-- %% [markdown]
-- ---
-- ![image.png](attachment:43545301-5d62-4ccf-95b1-cb89a7476503.png)

-- %%
dic = [("cat","felino"), ("cat","gato"), ("egg","ovo"), ("fox","raposa"), ("house","casa"), ("residence","casa")]

-- %% [markdown]
-- ---
-- ![image.png](attachment:4fd18475-8ae5-4a8d-b9e2-690290f0e4d5.png)

-- %%
dic |> collect

-- %% [markdown]
-- ---
-- ![image.png](attachment:eb534894-238c-4019-b820-06391d719a6a.png)

-- %%
elvish = ["aerister","bhin","bhin","lurleath","nor"]
english = ["teacher","young man","boy","sky","love"]

-- %%
elvish # english

-- %% [markdown]
-- ---
-- ![image.png](attachment:a67ee9f3-308f-4391-b811-d9d3cb587943.png)

-- %%
elvish # english |> collect

-- %%
elvish # english |> collect |> length
