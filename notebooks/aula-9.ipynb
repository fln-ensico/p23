-- %% [markdown]
-- # **Atividade | Grafos Pesados e Itinerários**
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:934c2533-07db-4aa2-a51e-ada9b8690395.png)
--
-- ---

-- %% [markdown]
-- #### ⚠️ **Importante**: correr a célula abaixo

-- %%
:opt no-lint
:m Data.List
:l ./src/ensico-g.hs

-- %% [markdown]
-- ---
-- #### ➡️ Vamos começar por dizer ao computador quais são os **nomes das cidades**:

-- %%
data Cidades = Bragança | Porto | Viseu | Coimbra | Portalegre | Lisboa 
    deriving (Eq, Ord, Show)

-- %% [markdown]
-- ---
-- ![image.png](attachment:1cb4cecb-fc83-4a4e-9ed8-404fa33bbd9a.png)

-- %%
mapa = [((Porto,Viseu),127),
        ((Porto,Coimbra),124),
        ((Viseu,Coimbra),93),
        ((Coimbra,Lisboa),204),
        ((Coimbra,Portalegre),172),
        ((Portalegre,Lisboa),227),
        ((Bragança,Porto),210)]

-- %% [markdown]
-- ---
-- ![image.png](attachment:8af4ffda-4b93-419f-b3b5-d89e586aba49.png)

-- %%
itinerário = [((Bragança,Porto),210),
            ((Porto,Viseu),127),
            ((Viseu,Coimbra),93),
            ((Coimbra,Portalegre),172),
            ((Portalegre,Lisboa),227)]

-- %% [markdown]
-- ---
-- ![image.png](attachment:983b9791-62e7-4db7-ade0-15683a886384.png)

-- %% [markdown]
-- #### ➡️ **1ª** componente:

-- %%
((Porto,Viseu),127) |> fst

-- %% [markdown]
-- #### ➡️ **2ª** componente:

-- %%
((Porto,Viseu),127) |> snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:1066a6e8-b7b9-44a4-8647-07ff658ca330.png)

-- %%
(Porto,Viseu) |> fst 
(Porto,Viseu) |> snd

-- %%
((Viseu,Coimbra),93) |> fst 
((Viseu,Coimbra),93) |> snd

-- %%
([1,2,3],(4,5)) |> fst
([1,2,3],(4,5)) |> snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:b4170c0e-abc3-4086-adbb-5b3a4bf168f4.png)

-- %%
itinerário |> map snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:aed70909-1952-4e9b-b783-43fba55b6745.png)

-- %%
[(Porto,Viseu),(Viseu,Coimbra)] |> map fst

-- %%
[(Porto,Viseu),(Viseu,Coimbra)] |> map snd

-- %%
[(1,2),(3,4)] |> map fst

-- %%
[(1,2),(3,4)] |> map snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:7e2c09b3-587b-48ce-8cb0-8f6c1e9077df.png)

-- %%
[210,127,93,172,227] |> sum

-- %% [markdown]
-- ---
-- ![image.png](attachment:c7b6ffa5-83f2-4caa-b5ef-25e0b4d71777.png)

-- %%
[1,3,5,7,9] |> sum

-- %%
[121,10,23] |> sum

-- %%
[[1,3,5],[2,4,6]] |> map sum

-- %% [markdown]
-- ---
-- ![image.png](attachment:775e83f2-4899-4a82-a1ff-3d7c947852af.png)

-- %%
itinerário |> map snd |> sum
