-- %% [markdown]
-- # **Atividade** | Sequências de Palavras e Transformações
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:02e71c05-40d0-47ff-8d66-ab9a5700297e.png)

-- %% [markdown]
-- ---
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar a célula seguinte</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:l ./src/ensico.hs
:m Data.Char
:m Data.List
:opt no-lint

-- %% [markdown]
-- ---
-- ![image.png](attachment:53ff5a15-e914-40ec-900c-c91a5a65dbcd.png)

-- %%
"Quero ir a Marte" |> words

-- %%
"O rato roeu a rolha do rei Roberto" |> words

-- %% [markdown]
-- ---
-- ![image.png](attachment:8939f151-4f6b-4242-a677-f1e47aedb035.png)

-- %% [markdown]
-- ### Alínea **a)**

-- %%
"Gosto de ti" |> words

-- %% [markdown]
-- ### Alínea **b)**

-- %%
"Gosto de ti" |> length

-- %% [markdown]
-- ### Alínea **c)**

-- %%
"Gosto de ti" |> words |> length

-- %% [markdown]
-- ---
-- ![image.png](attachment:b744da99-e58e-452f-bbea-f45e524d550c.png)

-- %%
["Quero","ir","a","Marte"] |> unwords

-- %%
["Fui","ao","cinema"] |> unwords

-- %% [markdown]
-- ---
-- ![image.png](attachment:7357f074-052e-4b56-b66e-cbed93a5a3c3.png)

-- %%
"Fui ao cinema" |> ... |> ... |> ...
