-- %% [markdown]
-- # **Atividade** | A Transformação **`map`**
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:02e71c05-40d0-47ff-8d66-ab9a5700297e.png)

-- %% [markdown]
-- ---
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar a célula seguinte</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:l ./src/ensico.hs
:m Data.Char
:m Data.List
:opt no-lint

-- %% [markdown]
-- ---
-- ![image.png](attachment:b085672f-bd06-4d69-957f-7e24d9cb7e7f.png)

-- %%
25 |> (+12)

-- %% [markdown]
-- ---
-- ![image.png](attachment:d60685a3-afa4-49d1-ac3d-43fea30f838d.png)

-- %%
11 |> (*8)

-- %% [markdown]
-- ---
-- ![image.png](attachment:2a4def50-82f4-4f42-af81-d99307f74ee2.png)

-- %%
[1,2,5,8] |> (+1)

-- %% [markdown]
-- ---
-- ![image.png](attachment:ddac051c-3ebc-4904-8e0d-7f716cac3ae0.png)

-- %%
[1,2,5,8] |> map

-- %% [markdown]
-- ---
-- ![image.png](attachment:cb58aca6-bf37-4a4a-aef9-492405b485c0.png)

-- %%
[1,2,5,8] |> map (+1)

-- %% [markdown]
-- ---
-- ![image.png](attachment:043949eb-9f45-4514-8830-e5d638c1b605.png)

-- %%
[1,2,5,8] |> map (*2)

-- %% [markdown]
-- ---
-- ![image.png](attachment:3e58d330-2fd5-4ec6-80df-a6ab9d95ea14.png)

-- %% [markdown]
-- ### Alínea **a)**

-- %%
[10,9,8] |> map (*3)

-- %% [markdown]
-- ### Alínea **b)**

-- %%
[3,1,3,2,7] |> map (+5)

-- %% [markdown]
-- ### Alínea **c)**

-- %%
["fui","ao","meu","tio"] |> map reverse

-- %% [markdown]
-- ### Alínea **d)**

-- %%
["eu","sou","de","cá"] |> map length

-- %% [markdown]
-- ### Alínea **e)**

-- %%
[3,5,1] |> map (+1) |> map (*3)

-- %% [markdown]
-- ---
--
-- ### ➡️ **Sequência gigante** - alguém a quer transformar à mão? 🤪

-- %%
[98156,811012,11304,524463,921283,437174,846054,175246,356430,34761,34688,756421,
    165201,576705,488611,305634,855065,616168,144269,868300,148935,167657,620267,981226,
    620890,582732,660066,369792,310596,973791,603183,188908,274316,178189,359402,504029,
    109298,463880,362762,874937,407690,804507,465225,88917,247124,810142,203357,966261,
    784851,562175,580739,55,4307,39137,925358,381568,848406,479135,526350,182237,18862,
    523363,587986,204443,80051,93057,543090,752116,12233,235126,842150,243959,327834,
    645337,307036,568528,295357,875215,537112,68635,566002,801019,517098,800411,250614,
    845802,399954,572262,579555,800,371,133415,148950,402451,105087,348196,859277,105352,
    390319,859222,877546,947218,375090,307940,511013,527122,37663,688145,551907,908508,
    797580,930970,308106,454231,831239,193933,361257,928088,107041,15255,407810,136615,
    214818,226388,578636,486996,121669,449163,919474,510280,869109,94649,674977,302384,
    787772,318156,819183,524017,281048,942012,583899,736924,603871,952257,394567,27401,
