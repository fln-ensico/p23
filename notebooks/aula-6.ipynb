-- %% [markdown]
-- # **Aula Prática** | Operadores e Circuitos Lógicos
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:02e71c05-40d0-47ff-8d66-ab9a5700297e.png)

-- %% [markdown]
-- ---
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar a célula seguinte</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:l ./src/ensico.hs
:m Data.Char
:m Data.List
:opt no-lint
(>>) = flip (.)

-- %% [markdown]
-- ---
-- ## **Introdução**
--
-- ### Nesta atividade vamos começar por definir as funções **`not`**, **`and`** e **`or`**.
--
-- ### Vamos começar? 😀

-- %% [markdown]
-- ---
-- ## **Exercício 1** | Operações Lógicas
--
-- ### **a)** Vamos começar por definir a função **`not`**.
--
-- ### **Completa** a célula seguinte de acordo com a tabela abaixo, que ilustra o comportamento da porta lógica **NOT**.
--
-- <img src="attachment:08e225d9-4b31-4039-a822-2950ccc8bf3c.png" style="width: 500px;">

-- %%
not 0 = ...
not 1 = ...

-- %% [markdown]
-- ### **b)** Agora, vamos definir a função **`and`**.
--
-- ### **Completa** a célula seguinte de acordo com a tabela abaixo, que ilustra o comportamento da porta lógica **AND**.
-- <img src="attachment:b644c67a-b62f-43ed-9d4f-da709ba54e77.png" style="width: 500px;">

-- %%
and 0 0 = ...
and 1 0 = ...
and 0 1 = ...
and 1 1 = ...

-- %% [markdown]
-- ### **c)** Finalmente, vamos definir a função **`or`**.
--
-- ### **Completa** a célula seguinte de acordo com a tabela abaixo, que ilustra o comportamento da porta lógica **OR**.
-- <img src="attachment:b404bb70-2a15-42f8-8e14-388a0aed5ba3.png" style="width: 500px;">

-- %%
or 0 0 = ...
or 1 0 = ...
or ... ... = ...
or ... ... = ...

-- %% [markdown]
-- ---
-- ## **Exercício 2** | Circuitos Lógicos
--
-- ### **a)** Analisa atentamente o **circuito lógico** abaixo.
--
-- <br>
--
-- <img src="attachment:d9f4c326-a47b-486a-a887-662e38ed6506.png" style="width: 900px;">
--
-- ### Considera também os seguintes valores para **A**, **B**, **C**, **D** e **E**:
--
-- * ### **A** = 1
-- * ### **B** = 1
-- * ### **C** = 0
-- * ### **D** = 1
-- * ### **E** = 1
--
-- ### Recorrendo às funções que acabaste de escrever, o valor de **`a`** é obtido através da seguinte expressão:
--
-- * ### `a = and 1 1`
--
-- ### Experimenta **executando** a célula abaixo.

-- %%
a = and 1 1

a

-- %% [markdown]
-- ### **a.1)** Escreve agora a expressão que te permite obter o valor de **`b`**.

-- %%
b = ...

-- %% [markdown]
-- ### **a.2)** Escreve agora as expressões que te permitem obter os valores de **`c`**, **`d`**, **`e`** e **`f`**.

-- %%
c = not ...
d = or ... ...
e = ...
f = ...

-- %% [markdown]
-- ### **a.3)** Executa agora a célula abaixo para verificares se o valor final é o que esperavas.

-- %%
f

-- %% [markdown]
-- ### **b)** Considera agora os seguintes valores para **A**, **B**, **C**, **D** e **E**:
--
-- * ### **A** = 0
-- * ### **B** = 0
-- * ### **C** = 0
-- * ### **D** = 1
-- * ### **E** = 1
--
-- <img src="attachment:9cdbf65f-0354-404f-a4ea-c7416e9a96db.png" style="width: 900px;">
--
-- ### **b.1)** Completa a célula abaixo de maneira a refletir o comportamento do **circuito lógico** para estes novos valores de **input**.

-- %%
a = and ... ... 
b = and ... ...
c = not a
d = or ... b
e = or c d
f = not e

-- %% [markdown]
-- ### **b.2)** Executa agora a célula abaixo para verificares se o valor final é o que esperavas.

-- %%
f

-- %% [markdown]
-- ### **b.3)** Agora utiliza valores à tua escolha para **A**, **B**, **C**, **D** e **E** de tal maneira que o resultado final seja **1**.

-- %%
a = and ... ... 
b = and ... ...
c = not a
d = or ... b
e = or c d
f = not e

-- %%
f
