-- %% [markdown]
-- # **Webinar** | Teaching Computation – The 2nd Cycle
--
-- ### Wed, May 3, 4:00 pm - 7:00 pm (GMT+1)
--
--
-- ![cs4all-consortium-short.png](attachment:6c649f76-c400-4d9a-8846-2aa2cd7de77f.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
-- ## **Part V** - Graphs

-- %% [markdown]
-- ---
-- ![image.png](attachment:4091497f-e4bf-40e6-8bcb-a082edd4b15a.png)

-- %%
data Cities = Bragança | Porto | Viseu | Coimbra | Portalegre | Lisboa
    deriving (Eq, Ord, Show)

-- %%
itinerary = [((Bragança,Porto),210),
             ((Porto,Viseu),127),
             ((Viseu,Coimbra),93),
             ((Coimbra,Portalegre),172),
             ((Portalegre,Lisboa),227)]

-- %% [markdown]
-- ![image.png](attachment:8014c5c5-457d-414a-b9d8-0c840e738abf.png)

-- %%
((Porto,Viseu), 127) |> fst

-- %%
((Porto,Viseu), 127) |> snd

-- %% [markdown]
-- ![image.png](attachment:6726e88b-3fbc-4b17-a4f2-95c019e36d63.png)

-- %%
(Porto,Viseu) |> fst

-- %%
(Porto,Viseu) |> snd

-- %%
((Viseu,Coimbra),93) |> fst

-- %%
((Viseu,Coimbra),93) |> snd

-- %% [markdown]
-- ![image.png](attachment:efb310db-83ae-421d-88e3-5427740084dd.png)

-- %%
itinerary |> map snd

-- %% [markdown]
-- ![image.png](attachment:3f8b31f0-85f5-41fe-8d13-7428e5c7afd2.png)

-- %%
itinerary |> map snd |> sum
