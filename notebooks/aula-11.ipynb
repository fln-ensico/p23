-- %% [markdown]
-- # **Aula Prática** | Campeonato de Futebol
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:934c2533-07db-4aa2-a51e-ada9b8690395.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar as células seguintes</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./src/ensico.hs

-- %% [markdown]
-- ---
-- ## **Exercício 1** | Quantos golos?
--
-- ### O grafo abaixo modela um **campeonado de futebol** fictício. Uma seta **`X`** $\rightarrow$ **`Y`** indica que o clube **`X`** marcou algum golo contra o clube **`Y`**, e o número por cima da seta indica **quantos golos** foram marcados.
-- ### Por exemplo, a seta **`Farense`** $\xrightarrow{5}$ **`Chaves`** indica que o **`Farense`** marcou $5$ golos contra o **`Chaves`**.

-- %% [markdown]
-- <img src="attachment:a0071678-cee9-4168-9d4a-16fa544588a6.png" style="width: 700px;">

-- %% [markdown]
-- ### **a)** Completa a célula abaixo com os **cinco clubes** representados no grafo.
-- #### **Nota:** os nomes dos cinco clubes têm de ser **iniciados com letra maiúscula**.

-- %%
data Clubes = Arouca | ... | ... | ... | ...  deriving (Eq,Show,Ord)

-- %% [markdown]
-- ### **b)** Completa a célula abaixo com a **sequência** que representa este grafo.

-- %%
campeonato = [((Arouca,Tondela),10),
             ...,
             ...,
             ...,
             ...,
             ...,
             ...]

-- %% [markdown]
-- ### **c)** Utiliza as funções **`map`** e **`snd`** para obter:
-- * ### uma **sequência numérica**, chamada **`golos`**, que regista apenas os **números de golos** assinalados no grafo.

-- %%
golos = campeonato |> ...

-- %% [markdown]
-- ### **d)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
golos

-- %% [markdown]
-- ### **e)** Utiliza a função **`sum`** para determinar quantos golos foram marcados **no total**.

-- %%
golos |> ...

-- %% [markdown]
-- ### **f)** Determina o **maior número de golos** que uma equipa marcou contra outra.
--
-- #### **Dica:** utiliza a função **`maximum`** (exemplo: **`[1,3,2] |> maximum = 3`**).

-- %%
golos |> ...

-- %% [markdown]
-- ---
--
-- ## **Exercício 2** | Golos marcados e sofridos
--
-- ### Queremos agora trabalhar com o **grafo sem etiquetas** que indica apenas que equipas **marcaram pelo menos um golo** contra outras equipas.
--
-- > #### Ou seja, este grafo regista apenas os **sucessos** que as equipas tiveram a marcar golos.
--
-- ![image.png](attachment:e9cb9971-7993-49b1-898d-fd60855b9fad.png)

-- %% [markdown]
-- ### **a)** Partindo da sequência **`campeonato`**, escreve um programa chamado **`sucessos`** que te permita obter a **sequência de pares** que representa este grafo mais simples.
--
-- ![image.png](attachment:0b14003e-14c1-419d-91fa-ff6e74f1a766.png)
--
-- #### Preenche a célula abaixo.

-- %%
sucessos = ...

-- %% [markdown]
-- ### **b)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
sucessos

-- %% [markdown]
-- ### **c)** Escreve um programa chamado **`marcou`** que te permita obter uma **sequência** com os **nomes** de todos os **clubes que marcaram algum golo** no campeonato.
--
-- > #### ⚠️ Não devem surgir nomes repetidos.
--
-- #### **Dicas:**
-- * #### primeiro, utiliza as funções **`map`** e **`fst`**;
-- * #### depois, utiliza a função **`nub`**, para eliminar os nomes repetidos.

-- %%
marcou = sucessos |> ... |> ...

-- %% [markdown]
-- ### **d)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
marcou

-- %% [markdown]
-- ### **e)** Escreve agora um programa chamado **`sofreu`** que te permita obter uma **sequência** com os **nomes** de todos os **clubes que sofreram algum golo** no campeonato.
--
-- > #### ⚠️ Não devem surgir nomes repetidos.

-- %%
sofreu = ...

-- %% [markdown]
-- ### **f)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
sofreu

-- %% [markdown]
-- ---
--
-- ## **Exercício 3** | Clubes goleados pelo Mafra

-- %% [markdown]
-- ### O objetivo deste exercício é dar instruções ao computador para determinar **contra quantas equipas** é que o **`Mafra`** marcou golos.
--
-- ### Graficamente, isto corresponde a determinar **quantas setas saem** do círculo que representa o clube **`Mafra`** no grafo.
--
-- ![image.png](attachment:e0e25fc5-b1c6-4c6e-b99a-d44c28868da7.png)
--
-- ### Ou seja, queremos determinar em **quantos** pares da sequência **`sucessos`** é que **`Mafra`** surge na **primeira componente**.

-- %% [markdown]
-- ### **a)** Começa por recordar a sequência **`sucessos`** que representa o grafo acima, executando a célula abaixo.

-- %%
sucessos

-- %% [markdown]
-- ### **b)** Escreve um programa chamado **`primeiras`** que te permita obter todas as **primeiras compontentes** dos pares da sequência **`sucessos`**.

-- %%
primeiras = ...

-- %% [markdown]
-- ### **c)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
primeiras

-- %% [markdown]
-- ### **d)** Agora, vamos querer **filtrar** a sequência **`primeiras`** de modo a obtermos apenas os elementos iguais a **`Mafra`**.

-- %% [markdown]
-- ### **d.1)** Para isso, vamos utilizar uma nova função, chamada **`filter`**.
--
-- #### Por exemplo, como podes confirmar abaixo, o resultado de:
-- * #### **`filter (== 3) [1,3,1,5,5,3,2]`**
--
-- #### é **`[3,3]`** uma vez que, na sequência **`[1,3,1,5,5,3,2]`**, há apenas dois elementos **iguais a `3`**. Os elementos **diferentes de `3`** foram ignorados.

-- %%
[1,3,1,5,5,3,2] |> filter (== 3)

-- %% [markdown]
-- #### No fundo, o computador perguntou a cada elemento "**és igual a `3`?**" e apenas manteve os elementos cuja resposta foi "**Sim**" 😄

-- %% [markdown]
-- ### **d.2)** Aplica a função **`filter`** à sequência **`primeiras`** de modo a ficares apenas com os elementos que são iguais a **`Mafra`**.

-- %%
primeiras |> ...

-- %% [markdown]
-- ### **e)** Por fim, utiliza a função **`length`** para obteres o número de elementos da sequência anterior.
--
-- #### O que concluis? Afinal, o **`Mafra`** marcou golos contra quantas equipas?

-- %%
primeiras |> ... |> ...

-- %% [markdown]
-- ---
-- ## **Exercício 4** | Clubes que golearam o Arouca

-- %% [markdown]
-- ### À semelhança do exercício anterior, o objetivo deste exercício é dar instruções ao computador para determinar **quantas equipas marcaram golos** contra o **`Arouca`**.
--
-- ### Graficamente, isto corresponde a determinar **quantas setas entram** no círculo que representa o clube **`Arouca`** no grafo.
--
-- ![image.png](attachment:5b400d07-f457-4c16-9485-3bb194a0b26c.png)
--
-- ### Ou seja, queremos determinar em **quantos** pares da sequência **`sucessos`** é que **`Arouca`** surge na **segunda componente**.

-- %% [markdown]
-- ### **a)** Escreve um programa chamado **`segundas`** que te permita obter todas as **segundas componentes** dos pares da sequência **`sucessos`**.

-- %%
...

-- %% [markdown]
-- ### **b)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
segundas

-- %% [markdown]
-- ### **c)** Aplica a função **`filter`** à sequência **`segundas`** de modo a ficares apenas com os elementos que são iguais a **`Arouca`**.

-- %%
...

-- %% [markdown]
-- ### **d)** Por fim, utiliza a função **`length`** para obteres o número de elementos da sequência anterior.
--
-- #### O que concluis? Afinal, o **`Arouca`** sofreu golos de quantas equipas?

-- %%
...
