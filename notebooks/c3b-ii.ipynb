-- %% [markdown]
-- # **Blended Mobility, Porto** | Teaching Computation — The 2nd Cycle
--
-- ### Tue, Jun 27, 9h30 - 12h30 (GMT+1)
--
--
-- ![erasmus-consortium-short.png](attachment:71ce7cc0-487b-4ef2-82b9-b100298a53d9.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
--
-- ## **PART II** | Characters and strings

-- %% [markdown]
-- ---
-- <span style="color:maroon">
--
-- ## **Useful functions on lists:**
--
-- * ### **`sum`** - returns the **sum** of all numbers in the list.
-- * ### **`maximum`** - returns the **greatest element** in the list.
-- * ### **`length`** - returns the **number of elements** in the list.
-- * ### **`sort`** - returns a new list with the elements in **ascending order**.
-- * ### **`reverse`** - returns a new list with the elements in **reverse order**.
-- * ### **`nub`** - returns a new list with all the **duplicates removed**.</span>

-- %% [markdown]
-- ---
-- ### 👉 Some examples of **characters**:

-- %%
'a'

-- %%
'.'

-- %%
'@'

-- %% [markdown]
-- ---
-- ### 👉 Some examples of **strings**:

-- %%
"banana"

-- %%
"I want a million dollars, now."

-- %%
['H','e','l','l','o',' ','w','o','r','l','d','!']

-- %% [markdown]
-- ---
-- ## ➡️ **Activity 1**

-- %% [markdown]
-- ### The **longest word** in the English dictionary is
-- > ### "pneumonoultramicroscopicsilicovolcanoconiosis"

-- %% [markdown]
-- ### **a)** How many **letters** does this word have?

-- %%
"pneumonoultramicroscopicsilicovolcanoconiosis" |> ...

-- %% [markdown]
-- ### **b)** If we write this word **backwards**, what do we get?

-- %%
"pneumonoultramicroscopicsilicovolcanoconiosis" ...

-- %% [markdown]
-- ### **c)** If we **order** the letters of this word **alphabetically**, what word do we get?

-- %%
"pneumonoultramicroscopicsilicovolcanoconiosis" ...

-- %% [markdown]
-- ### **d)** If we eliminate **repeated** letters, what word do we get?

-- %%
"pneumonoultramicroscopicsilicovolcanoconiosis" ...

-- %% [markdown]
-- ### **e)** How many letters does the word above (without repeated letters) have?

-- %%
"pneumonoultramicroscopicsilicovolcanoconiosis" ...

-- %% [markdown]
-- ---
-- ![image.png](attachment:eaa38f29-13a7-47a9-a8ed-e898e8fdce96.png)

-- %%
"Teaching is the greatest act of optimism" |> length

-- %% [markdown]
-- ---
-- ![image.png](attachment:0a0b904f-b79c-4895-848d-baa9d60fa1c9.png)

-- %%
"I really like computers" |> words

-- %% [markdown]
-- ---
-- ## ➡️ **Activity 2**

-- %% [markdown]
-- ### **a)** How many **characters** (letters and spaces) does the sentence
-- > ### "A big black bug bit a big black bear and made the big black bear bleed blood"
-- ### have?

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ### **b)** Transform the sentence above into the **list of words** that constitute it.

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ### **c)** How many **words** does that sentence have?

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ---
-- ![image.png](attachment:20da44fd-d018-4e31-a808-bbd6f08aa814.png)

-- %%
["I", "really", "like", "computers"] |> unwords

-- %% [markdown]
-- ---
-- ## ➡️ **Activity 3**

-- %% [markdown]
-- ### In **Star Wars**, the character **Yoda** speaks **backwards**, meaning that he reverses the order by which the words appear in the sentence.
--
-- <div style="text-align:center"><img src="attachment:b946f712-8dce-4f87-a4a7-920c939b12d9.png" style="width: 500px;"></div>
--
-- ### For instance, instead of saying
--
-- > ### **`"I really like computers"`** (1)
--
-- ### he would say
--
-- > ### **`"computers like really I"`** (2)

-- %% [markdown]
-- ### **a)** If you apply the function **`reverse`** to sentence (1), do you get sentence (2)?

-- %%
"I really like computers" ...

-- %% [markdown]
-- ### **b)** Write an **expression** to transform sentence (1) into sentence (2).

-- %%
"I really like computers" ...

-- %% [markdown]
-- ### **c)** **Translate** the sentence
-- > ### "A big black bug bit a big black bear and made the big black bear bleed blood"
-- ### into "Yoda's language".

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...
