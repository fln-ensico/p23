-- %% [markdown]
-- # **Blended Mobility, Porto** | Teaching Computation — The 2nd Cycle
--
-- ### Tue, Jun 27, 14h30 - 17h30 (GMT+1)
--
--
-- ![erasmus-consortium-short.png](attachment:71ce7cc0-487b-4ef2-82b9-b100298a53d9.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
--
-- ## **PART VI** | Graphs

-- %% [markdown]
-- ---
-- ![image.png](attachment:3685d1f7-84b3-45d8-baa5-6d8b6b312e72.png)

-- %%
data Cities = Bragança | Porto | Viseu | Coimbra | Portalegre | Lisboa 
    deriving (Eq, Ord, Show)

-- %%
itinerary = [((Bragança,Porto),210),
             ((Porto,Viseu),127),
             ((Viseu,Coimbra),93),
             ((Coimbra,Portalegre),172),
             ((Portalegre,Lisboa),227)]

-- %% [markdown]
-- ---
-- ![image.png](attachment:91f9c23f-25bb-4764-9c58-302861effc53.png)

-- %%
((Porto,Viseu),127) |> fst

-- %%
((Porto,Viseu),127) |> snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:5dbd1cbb-0ef3-4db9-8171-92358062618d.png)

-- %%
(Porto,Viseu) |> fst

-- %%
(Porto,Viseu) |> snd

-- %%
((Viseu,Coimbra),93) |> fst

-- %%
((Viseu,Coimbra),93) |> snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:93b29cc1-a4d4-4936-ba9b-4f236ea6d3a2.png)

-- %%
itinerary |> map snd

-- %% [markdown]
-- ---
-- ![image.png](attachment:4fc354dc-b206-4e42-a8d6-6f5ea3305f71.png)

-- %%
itinerary |> map snd |> sum
