-- %% [markdown]
-- # **Atividade** | Sequências de Caracteres e Transformações
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:02e71c05-40d0-47ff-8d66-ab9a5700297e.png)

-- %% [markdown]
-- ---
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar a célula seguinte</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:l ./src/ensico.hs
:m Data.Char
:m Data.List
:opt no-lint

-- %% [markdown]
-- ---
-- ![image.png](attachment:6f467612-2eb2-452b-9ca0-179c32eb522b.png)

-- %%
['J','o','e','l']

-- %% [markdown]
-- ---
-- ![image.png](attachment:90b035bd-a2c6-481d-b662-7395e5c14192.png)

-- %%
"gato" |> sort

-- %%
"Joel Nuno" |> reverse

-- %%
"gato" |> sort |> reverse

-- %%
"Joel Nuno" |> nub |> length

-- %%
"cinco" |> maximum
