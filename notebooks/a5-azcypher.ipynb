-- %% [markdown]
-- # **Atividade** | A Cifra "A-Z"
--
-- ## com o apoio do [Departamento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- [<img src="attachment:53689f31-ebda-470d-826c-350210b7361c.png" width="90%">](https://ensico.pt/sobre/)
--
-- ---

-- %% [markdown]
-- #### <span style="color:darkred">⚠️ **Importante**:</span> executar a célula abaixo  (com o cursor na célula: botão ▶️  ou **shift + enter**)

-- %%
:opt no-lint
:m Data.List
:m Data.Char
:l ./src/ensico.hs
(>>) = flip (.)

-- %% [markdown]
-- ---
-- ## **A Cifra "A-Z"**
--
-- A **Cifra "A-Z"** é uma cifra **simétrica** que consiste em trocar o **`A`** com o **`Z`**, o **`B`** com o **`Y`**, o **`C`** com o **`X`**, etc.
--
-- ![image.png](attachment:f1ef76f3-4f59-4f81-8218-86f2a8ccb43a.png)
--
-- **Problema**. Vamos definir o **super-robot** **`cifraAZ`** em **5 passos**. Este **super-robot** permitirá cifrar e decifrar mensagens através da **Cifra "A-Z"**. 🤖🦾
--
-- **Sugestão**. Começar por analisar e registar a informação relativa às transformações ilustradas nos **passos 1**, **2** e **3** do gráfico abaixo, concluindo depois o exercício com os **passos 4** e **5**.
--
-- * **Passo 1.** Queremos registar a transformação de todas as **letras maiúsculas** nos respetivos **códigos decimais ASCII**. Que transformação será essa?
-- * **Passo 2.** Queremos registar a transformação de todas as **letras maiúsculas** nos respetivos **códigos decimais ASCII**, ordenando-os por **ordem decrescente**.
-- * **Passo 3.** O emparelhamento dos números obtidos nos **passos 1** e **2** em **pares de números** permitirá identificar a **troca de letras** associada à **Cifra "A-Z"**. Que transformação será essa?
-- * **Passo 4.** Efectuar a **troca de letras** através dos seus **códigos decimais ASCII**.
-- * **Passo 5.** Definir o **super-robot** :robot: **`cifraAZ`**.
--
-- ![image.png](attachment:12d5d985-62c8-42b3-a595-e6d558b01a2b.png)

-- %% [markdown]
-- ---
-- **Passo 1.** Completa as **`...`** na expressão abaixo com a instrução que te permitirá obter a **lista dos códigos decimais ASCII** das **letras maiúsculas**.
--
-- Associa o nome **`az`** a esse resultado.

-- %%
az = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`az`** executando a célula abaixo.

-- %%
az

-- %% [markdown]
-- ---
-- **Passo 2.** Partindo do resultado anterior, que ficou associado ao nome **`az`**, completa as **`...`** na expressão abaixo com a instrução que te permitirá obter, pela ordem invertida, a **lista dos códigos decimais ASCII** das letras maiúsculas.
--
-- Associa o nome **`za`** a esse resultado.

-- %%
za = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`za`** executando a célula abaixo.

-- %%
za

-- %% [markdown]
-- ---
-- **Passo 3.** Completa as **`...`** na expressão abaixo com a instrução que te permitirá **emparelhar** os códigos registados em **`az`** e **`za`**.
--
-- Associa o nome **`cifra`** a esse resultado.

-- %%
cifra = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`cifra`** executando a célula abaixo.

-- %%
cifra

-- %% [markdown]
-- ---
-- **Passo 4.** Considera a função **`lkp`** que, **para uma dada lista de pares**, permite obter o **segundo elemento de um par** a partir do **primeiro elemento desse par**.
--
-- Por exemplo, partindo da lista **`cifra`** obtida no **passo 3**, **`cifra = [(65,90),(66,89),(67,88),...,(88,67),(89,66),(90,65)]`**:
--
-- * a expressão **`65 |> lkp cifra`** dá como resultado **`90`**;
-- * a expressão **`88 |> lkp cifra`** dá como resultado **`67`**.
--
-- ▶️ Recorrendo à função **`lkp`**, completa as **`...`** na expressão abaixo com a instrução que te permitirá obter a letra **`Z`** (caractere **`'Z'`**) a partir da letra **`A`** (caractere **`'A'`**).

-- %%
'A' |> ... |> ... |> ...

-- %% [markdown]
-- ---
-- **Passo 5.** Completa as **`...`** na expressão abaixo e define agora o **super-robot** **`cifraAZ`** que transforma uma **letra maiúscula** numa outra **letra maiúscula**, segundo a **Cifra "A-Z"**.
--
-- Por exemplo, espera-se que a expressão **`'X' |> cifraAZ`** dê como resultado **`'C'`**.
--
-- ![super-robot-3.jpeg](attachment:38e4928c-a2ba-4bf1-a458-3bf8bb8d018a.jpeg)

-- %%
cifraAZ = ...

-- %% [markdown]
-- ▶️ Verifica o correto funcionamento do **super-robot** **`cifraAZ`** executando a célula abaixo.

-- %%
'X' |> cifraAZ

-- %% [markdown]
-- ---
-- **Passo 6.** Completa as **`...`** na expressão abaixo por forma a definir o **robot** **`msgAZ`**, tornando assim mais fácil a aplicação da **Cifra "A-Z"** a mensagens (*strings*).
--
-- Por exemplo, espera-se que a expressão **`"AZ" |> msgZA`** dê como resultado **`"ZA"`**.

-- %%
msgAZ = ...

-- %% [markdown]
-- ▶️ Verifica o correto funcionamento do **robot** **`msgAZ`** executando a célula abaixo.

-- %%
"AZ" |> msgAZ

-- %% [markdown]
-- ---
-- ## **1. Atividades**

-- %% [markdown]
-- **1.1.** ▶️ Completa as **`...`** na expressão abaixo por forma a aplicares o **robot** **`msgAZ`** à mensagem **`"ENSICO"`**.

-- %%
"ENSICO" |> ...

-- %% [markdown]
-- ---
-- **1.2.** ▶️ Completa as **`...`** na expressão abaixo por forma a obteres a mensagem original **`"ENSICO"`** após ter sido cifrada pela **Cifra "A-Z"**.

-- %%
"ENSICO" |> msgAZ |> ...

-- %% [markdown]
-- ---
-- **1.3.** Como te recordas, os **robots** **`cifraCesar`** e **`decifraCesar`** permitem decifrar mensagens (*strings*) cifradas pela **Cifra de César**.
--
-- ▶️ Executa as células abaixo por forma a poderes usar os **robots** **`cifraCesar`** e **`decifraCesar`** na resolução de algumas das questões que se seguem.

-- %%
cifraCesar = map (ord >> (+3) >> chr)

-- %%
decifraCesar = map (ord >> (+(-3)) >> chr)

-- %% [markdown]
-- ---
-- **1.4.** Alguém cifrou uma mensagem aplicando a **Cifra de César** e, de seguida, a **Cifra "A-Z"**, obtendo **`"WHFSJTSF"`**.
--
-- ▶️ Completa as **`...`** na expressão abaixo e utiliza os **robots** **`decifraCesar`** e **`msgAZ`** por forma a obteres a mensagem original.

-- %%
"WHFSJTSF" |> ...

-- %% [markdown]
-- ---
-- ## **2. A Cifra "A-Z" melhorada**

-- %% [markdown]
-- Observa atentamente cada uma das expressões que escreveste para os **passos 1, 2** e **3**.
--
-- Redefine-as por forma a **alargar** a definição do **super-robot** **`cifraAZ`** às **letras minúsculas**.
--
-- Por exemplo, se aplicarmos a **nova Cifra "A-Z"** à *string* **`"Astronauta"`**, o resultado deverá ser **`"Dsuhqghu"`**.
--
-- ![image.png](attachment:ebf75fe7-5ac2-4361-902d-347d959c8746.png)

-- %% [markdown]
-- ---
-- **2.1. Redefinição do passo 1.** Completa as **`...`** na expressão abaixo com a instrução que te permitirá obter a **lista dos códigos decimais ASCII** das **letras minúsculas**.
--
-- Associa o nome **`az'`** a esse resultado.

-- %%
az' = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`az'`** executando a célula abaixo.

-- %%
az'

-- %% [markdown]
-- ---
-- **2.2. Redefinição do passo 2.** Partindo do resultado anterior, que ficou associado ao nome **`az'`**, completa as **`...`** na expressão abaixo com a instrução que te permitirá obter, pela ordem invertida, a **lista dos códigos decimais ASCII** das **letras minúsculas**.
--
-- Associa o nome **`za'`** a esse resultado.

-- %%
za' = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`za'`** executando a célula abaixo.

-- %%
za'

-- %% [markdown]
-- ---
-- **2.3. Redefinição do passo 3.** Completa as **`...`** na expressão abaixo com a instrução que te permitirá **emparelhar** os códigos registados em **`az'`** e **`za'`**.
--
-- Associa o nome **`cifra'`** a esse resultado.

-- %%
cifra' = ...

-- %% [markdown]
-- ▶️ Verifica o valor de **`cifra'`** executando a célula abaixo.

-- %%
cifra'

-- %% [markdown]
-- ---
-- **2.4. Redefinição do passo 4.** Começa por executar as duas células abaixo para recordares os valores das cifras **`cifra`** e **`cifra'`**.

-- %%
cifra

-- %%
cifra'

-- %% [markdown]
-- ▶️ Recorrendo às cifras **`cifra`** e **`cifra'`**, completa as **`...`** na expressão abaixo e define uma **nova cifra** que **junte** ambas.
--
-- Associa o resultado ao nome **`cifra''`**.

-- %%
cifra'' = ...

-- %% [markdown]
-- ▶️ Verifica o resultado executando a célula abaixo.

-- %%
cifra''

-- %% [markdown]
-- ---
-- **2.5. Redefinição do passo 5.** Redefine o **super-robot** **`cifraAZ`** por forma a transformar uma **letra maiúscula** ou **minúscula** numa outra **letra maiúscula** ou **minúscula**, respetivamente, segundo a **Cifra "A-Z"**.
--
-- Por exemplo, espera-se que:
--
-- * a expressão **`'X' |> cifraAZ`** dê como resultado **`'C'`** e que
-- * a expressão **`'x' |> cifraAZ`** dê como resultado **`'c'`**.
--
-- ▶️ Completa as **`...`** na expressão abaixo por forma a redefinir **`cifraAZ`** usando, desta vez, a cifra **`cifra''`**.

-- %%
cifraAZ = ...

-- %% [markdown]
-- ---
-- **2.6.** **Redefinição do passo 6.** Completa as **`...`** na expressão abaixo por forma a redefinir o **robot** **`msgAZ`**, tornando assim mais fácil a aplicação da **nova Cifra "A-Z"** a mensagens (*strings*).
--
-- Por exemplo, espera-se que a expressão **`"Az" |> msgZA`** dê como resultado **`"zA"`**.

-- %%
msgAZ = ...

-- %% [markdown]
-- ▶️ Verifica o correto funcionamento do **robot** **`msgAZ`** executando a célula abaixo.

-- %%
"Az" |> msgAZ

-- %% [markdown]
-- ---
-- ## **3. Atividades**

-- %% [markdown]
-- **3.1.** ▶️ Completa as **`...`** nas expressões abaixo e utiliza os **super-robots** **`decifra`** e **`cifraAZ`** por forma a obteres a mensagem original associada às seguintes mensagens cifradas com a **Cifra de César** e, de seguida, com a **Cifra "A-Z"**:
--
-- * **"whfsjtsf"** (uma *string* com letras minúsculas);
-- * **"Whfsjtsf"** (uma *string* com a primeira letra maiúscula).

-- %%
"whfsjtsf" |> ...

-- %%
"Whfsjtsf" |> ...

-- %% [markdown]
-- **3.2.** ▶️ Completa as **`...`** nas expressões abaixo e utiliza os **robots** **`decifraCesar`** e **`msgAZ`** por forma a obteres a mensagem original associada às seguintes mensagens cifradas com a **Cifra de César** e, de seguida, com a **Cifra "A-Z"**:
--
-- * **"Gcsfi esf ck wedfijwcdw hwfw of w Kwfds"**;
-- * **"Qiedwbw ts bownwf jck toeui biwtif"** (uma *string* com a primeira letra maiúscula).
--
-- **Nota.** São sempre tão úteis as transformações **`words`** e **`unwords`**. 😀

-- %%
"Gcsfi esf ck wedfijwcdw hwfw of w Kwfds" |> ... |> ... |> ... |> ...

-- %%
"Qiedwbw ts bownwf jck toeui biwtif" |> ... |> ... |> ... |> ...
