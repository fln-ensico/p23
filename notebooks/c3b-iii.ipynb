-- %% [markdown]
-- # **Blended Mobility, Porto** | Teaching Computation — The 2nd Cycle
--
-- ### Tue, Jun 27, 9h30 - 12h30 (GMT+1)
--
--
-- ![erasmus-consortium-short.png](attachment:71ce7cc0-487b-4ef2-82b9-b100298a53d9.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
--
-- ## **PART III** | Higher order functions

-- %% [markdown]
-- ---
-- ![image.png](attachment:2859a87a-29fc-4701-9e16-c3b7c187c648.png)

-- %%
["You", "should", "study", "math"] |> reverse

-- %% [markdown]
-- ---
-- ![image.png](attachment:02012100-cddb-4290-bce4-7b67b1930694.png)

-- %% [markdown]
-- ---
-- ![image.png](attachment:20262f1f-5390-436b-94a4-75bdeb857f31.png)

-- %%
["You", "should", "study", "math"] |> map

-- %% [markdown]
-- ---
-- ![image.png](attachment:3171360f-f9ec-41c5-8b9b-7e2e916d072a.png)

-- %%
["You", "should", "study", "math"] |> map reverse

-- %% [markdown]
-- ---
-- ![image.png](attachment:96c0e671-54a2-43a8-9d50-4c83de984cae.png)

-- %% [markdown]
-- ---
-- ![image.png](attachment:5c82350c-2ddd-48f1-bc62-0cda18ca15a9.png)

-- %% [markdown]
-- ---
-- ![image.png](attachment:b733740f-189e-404f-96c3-3492ca962aff.png)

-- %%
["You", "should", "study", "math"] |> map length

-- %% [markdown]
-- ---
-- ![image.png](attachment:50161d4e-00c9-4548-b1d3-0f8cf4160c0b.png)

-- %% [markdown]
-- ---
-- ## ➡️ **Activity 4**

-- %% [markdown]
-- ### Recall the sentence:
-- > ### "A big black bug bit a big black bear and made the big black bear bleed blood"

-- %% [markdown]
-- ### **a)** Write an expression to transform this sentence into a **numeric list** with the **number of letters** in each word.

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ### **b)** Apply one more transformation at the end of the previous expression to get the **total number of letters** in the sentence.

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ### **c)** Write an expression to **reverse** each word in the sentence above.
--
-- > #### **Remark:** The result should be a *string* and not a list of *strings*.

-- %%
"A big black bug bit a big black bear and made the big black bear bleed blood" ...

-- %% [markdown]
-- ---
-- ## ➡️ **Activity 5**

-- %% [markdown]
-- ### Consider the list:
-- > ### **`[[6,2,2], [3,1,4], [5,1,2]]`**

-- %% [markdown]
-- ### **a)** Write an expression to **sort each numeric list** in the list above in **increasing order**.

-- %%
[[6,2,2], [3,1,4], [5,1,2]] ...

-- %% [markdown]
-- ### **b)** Write an expression to **sort each numeric list** in the list above in **decreasing order**.

-- %%
[[6,2,2], [3,1,4], [5,1,2]] ...

-- %% [markdown]
-- ### **c)** Write an expression to compute the **sum** of all the numbers that constitute the elements of the list above.

-- %%
[[6,2,2], [3,1,4], [5,1,2]] ...
