-- %% [markdown]
-- # **Aula Prática** | *Instagram*
--
-- ## com o apoio do [Departmento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- ![image.png](attachment:934c2533-07db-4aa2-a51e-ada9b8690395.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Importante**: executar as células seguintes</span>
-- #### <span style="color:darkblue"> (botão `Play` ou teclas `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./src/ensico-g.hs

-- %% [markdown]
-- ---
-- ## **Exercício 1** | Quantos *likes*?
-- ### O grafo abaixo ilustra **quem segue quem** no *Instagram*.
--
-- ### Além disso, os **números** das setas indicam a **quantidade de *likes*** que uma pessoa colocou nas publicações de outra.

-- %% [markdown]
-- <img src="attachment:a7c7d50a-9270-4354-964a-0a9ea4fbd0a3.png" style="width: 600px;">
--
-- #### 👉 Por exemplo, quando vemos **`Ana`** $\stackrel{10}{\longrightarrow}$ **`Eva`**, ficamos a saber que a **`Ana`** colocou um total de **10 *likes*** nas publicações da **`Eva`**.

-- %% [markdown]
-- ### **a)** Completa a célula abaixo com os **quatro utilizadores** representados no grafo.
-- #### **Nota:** os nomes dos quatro utilizadores têm de ser iniciados com letra maiúscula.

-- %%
data Utilizadores = ... | ... | ... | ...  deriving (Eq,Show,Ord)

-- %% [markdown]
-- ### **b)** Completa a célula abaixo com a **sequência** que representa este grafo.

-- %%
instagram = [((Ana,Paulo),19),
             ...,
             ...,
             ...,
             ...,
             ...]

-- %% [markdown]
-- ### **c)** Utiliza as funções **`map`** e **`snd`** para obter:
-- * ### uma **sequência numérica**, chamada **`likes`**,  que regista apenas as **quantidades de *likes*** trocados entre cada par de amigos.
--
-- ![image.png](attachment:b9cb2b7c-2a4d-49f5-8051-8183d3833779.png)
--
-- #### Preenche a célula abaixo.

-- %%
likes = ... |> ...

-- %% [markdown]
-- ### **d)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
likes

-- %% [markdown]
-- ### **e)** Utiliza a função **`sum`** para determinar quantos *likes* foram trocados **no total** entre o grupo de amigos acima.

-- %%
likes |> ...

-- %% [markdown]
-- ### **f)** Determina o **maior número de *likes*** que alguém colocou no perfil de outra pessoa.
--
-- #### **Dica:** utiliza a função **`maximum`** (exemplo: o resultado de **`[1,3,2] |> maximum`** é **`3`**).

-- %%
likes |> ...

-- %% [markdown]
-- ---
--
-- ## **Exercício 2** | Relações
--
-- ### Queremos agora trabalhar com o **grafo sem etiquetas** que indica apenas quem segue quem no *Instagram*.
--
-- > #### Ou seja, este grafo regista apenas as **relações** entre os vários amigos no *Instagram*.
--
-- <img src="attachment:3cf666b2-823d-420a-b67a-ddc1ede03ec2.png" style="width: 600px;">

-- %% [markdown]
-- ### **a)** Partindo da sequência **`instagram`**, escreve um programa chamado **`relacoes`** que te permita obter a **sequência de pares** que representa este grafo mais simples.
--
-- ![image.png](attachment:51be861e-b151-46ff-819a-6588f60cc762.png)
--
-- #### Preenche a célula abaixo.

-- %%
relacoes = ...

-- %% [markdown]
-- ### **b)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
relacoes

-- %% [markdown]
-- ### **c)** Escreve um programa chamado **`segue_alguem`** que te permita obter uma **sequência** com os **nomes** de todos os jovens que **seguem alguém** no *Instagram*.
--
-- > #### ⚠️ Não devem surgir nomes repetidos.
--
-- #### **Dicas:**
-- * #### primeiro, utiliza as funções **`map`** e **`fst`**;
-- * #### depois, utiliza a função **`nub`**, para eliminar os nomes repetidos.

-- %%
segue_alguem = ...

-- %% [markdown]
-- ### **d)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
segue_alguem

-- %% [markdown]
-- ### **e)** Escreve agora um programa chamado **`tem_seguidores`** que te permita obter uma **sequência** com os **nomes** de todos os jovens que **são seguidos por alguém**.
--
-- > #### ⚠️ Não devem surgir nomes repetidos.

-- %%
tem_seguidores = ...

-- %% [markdown]
-- ### **f)** Confirma que escreveste a instrução correta executando a célula abaixo.

-- %%
tem_seguidores
