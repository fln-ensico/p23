-- %% [markdown]
-- ## **Webinar** | Teaching Computation – The 2nd Cycle
--
-- ### Wed, May 3, 4:00 pm - 7:00 pm (GMT+1)
--
--
-- ![cs4all-consortium-short.png](attachment:6c649f76-c400-4d9a-8846-2aa2cd7de77f.png)
--
-- ---

-- %% [markdown]
-- ### <span style="color:darkblue"> ⚠️ **Important**: please execute the cell bellow</span>
-- #### <span style="color:darkblue"> (put the cursor there and then click the button ▶️ or press `Shift + Enter`) </span>

-- %%
:opt no-lint
:m Data.Char
:m Data.List
:l ./scripts/ensico.hs

-- %% [markdown]
-- ---
-- ## **Part II** - Higher Order Functions

-- %% [markdown]
-- ---
-- ![image.png](attachment:70ca3831-d5d2-4b3c-81d1-0aa8729c8867.png)

-- %%
25 |> (+12)

-- %% [markdown]
-- ![image.png](attachment:62a4d313-c852-4a38-983e-841c60c755d2.png)

-- %%
11 |> (*8)

-- %% [markdown]
-- ![image.png](attachment:a7be65dd-3250-4712-8a04-3ab4905fe1ee.png)

-- %%
3 |> (*9)

-- %%
5 |> (*10) |> (+2)

-- %%
5 |> (+2) |> (*10)

-- %% [markdown]
-- ![image.png](attachment:5c1f50c6-ab87-4ad9-9780-48bf170921cb.png)

-- %%
[1,2,5,8] |> (+1)

-- %% [markdown]
-- ![image.png](attachment:5c00e6c6-d6b2-411b-9c00-bb8ce97cc0f5.png)

-- %%
[1,2,5,8] |> map

-- %% [markdown]
-- ---
-- ![image.png](attachment:bb6f5a13-648c-48ac-a268-0fc0dd06b860.png)

-- %%
[1,2,5,8] |> map (+1)

-- %% [markdown]
-- ![image.png](attachment:9220e0c0-d5dc-4b87-8263-a1ace9825b23.png)

-- %%
[1,2,5,8] |> map (*2)

-- %% [markdown]
-- ![image.png](attachment:d5a4aa7e-7ee7-4f7c-a404-698d7cb0b51f.png)

-- %%
[10,9,8] |> map (*3)

-- %%
[3,1,3,2,7] |> map (+5) |> map (*2)

-- %%
["I","like","math"] |> map reverse
