-- %% [markdown]
-- <span style="color:darkblue"> ⚠️ **IMPORTANTE**</span>: **CORRE O CÓDIGO SEGUINTE** antes de começares a aula, senão alguns códigos não vão funcionar!
-- <br><span style="color:gray">(Para isso, clica na caixa de código abaixo e depois carrega no botão ![image.png](./assets/play.PNG) que está na barra em cima).</span>

-- %%
:m Data.List
:l scripts/ensico.hs

-- %% [markdown]
-- ---
--
-- # Aula 17 - Sequências Numéricas e transformações (parte 1)
-- > © 2020-2023 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- ---
-- ![image.png](attachment:3f035f32-b677-4972-b3f2-0377c57adfa6.png)

-- %% [markdown]
-- ### ➡️ **Sequências**

-- %%
[80,35,123,35,18]

-- %% [markdown]
-- * #### Podemos colocar espaços entre as vírgulas e os números, não interfere:

-- %%
[80, 35, 123, 35, 18]

-- %%
[80  ,    35,123, 35,  18]

-- %% [markdown]
-- * #### Mas o que acontece se nos esquecermos dos parênteses **`[ ... ]`**?

-- %%
80,35,123,35,18

-- %% [markdown]
-- * #### O que acontece se colocarmos pontos **`.`** em vez de vírgulas **`,`**?

-- %%
[80.35.123.35.18]

-- %% [markdown]
-- #### **Conclusão:** Temos de escrever tudo direitinho, com **parênteses** e **vírgulas**! 😃

-- %% [markdown]
-- ---
-- ![image.png](attachment:dbe79ecc-18dc-4bb4-97ff-ed3300813ba0.png)
-- ### ➡️ **Soma** de todos os números de uma sequência:

-- %%
[80, 35, 123, 35, 18] |> sum

-- %% [markdown]
-- ---
-- ![image.png](attachment:926c5c43-ac78-45da-8f66-1f4e31986e7e.png)

-- %%
[527, 413, ...]

-- %% [markdown]
-- ![image.png](attachment:05906daf-416a-4edf-a812-84d9785391f0.png)

-- %%
[527, 413, 377, 367, 356] ...

-- %% [markdown]
-- ---
-- ![image.png](attachment:5417eb1b-fcc8-49c3-91c3-6d129adc3593.png)
-- ### ➡️ Número **máximo** que ocorre numa sequência:

-- %%
[80, 35, 123, 35, 18] ...

-- %% [markdown]
-- ---
-- ![image.png](attachment:029ef690-ca78-4ecb-a756-ea1236475bf2.png)

-- %% [markdown]
-- ### **a)** Sequência:

-- %%
...

-- %% [markdown]
-- ![image.png](attachment:ddaa79c1-bdde-4cb3-bf1f-bba1d33617b9.png)

-- %% [markdown]
-- ### **b.1)** Soma:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **b.2)** Máximo:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ![image.png](attachment:fae5bab8-e80a-481a-8eae-547622ca0b0e.png)

-- %% [markdown]
-- ### **b.3)** Ordenar de forma crescente:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **b.4)** Eliminar elementos repetidos:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ![image.png](attachment:a31bd7cc-9410-4700-949f-25bdd8d792b1.png)

-- %% [markdown]
-- ### **c)** A transformação **`reverse`**:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **d)** A transformação **`length`**:

-- %%
[130, 859, 18, 250, 18, 250] ...
